# 5951  Thank you for the opportunity \nto address the...
# 6143  I am pleased to be here to \naddress the Gener...
# 6336  It is my honour to address the \nAssembly for ...
# 6526  It is a great honour to address \nthis Assembl...
# 6719  It is a great honour for me to \nbe here today...
# 6914  ﻿I would like to begin today by\ntelling the A...
# 7107  Each year we come together to \nreaffirm the f...
# 7301  We come together at a \ncrossroads between war...
# 7495  Seventy years after the founding of the United...

# %%
# show rows for Canada
df[ df["country_name"] == 'Canada' ]
# Out:
#       session  year country country_name                   speaker  \
# 8          25  1970     CAN       Canada                 Mr. SHARP
# 84         26  1971     CAN       Canada                 Mr- Sharp
# 204        27  1972     CAN       Canada                Mr. Sharp
# 329        28  1973     CAN       Canada                     Sharp
# 451        29  1974     CAN       Canada             Mr. MacEachen
# 580        30  1975     CAN       Canada             Mr. MacEACHEN
# 706        31  1976     CAN       Canada              Mr. Jamieson
# 841        32  1977     CAN       Canada                  JAMIESON
# 981        33  1978     CAN       Canada                  Jamieson
# 1121       34  1979     CAN       Canada                  McDonald
# 1267       35  1980     CAN       Canada                 MacGuigan
# 1416       36  1981     CAN       Canada             Mr. MACGUIGAN
# 1563       37  1982     CAN       Canada                MacEACHEN
# 1710       38  1983     CAN       Canada                 MacEACHEN
# 1859       39  1984     CAN       Canada                    CLARKE
# 2007       40  1985     CAN       Canada                 Mr. Clark
# 2146       41  1986     CAN       Canada                Mr. CLARK
# 2295       42  1987     CAN       Canada                    CLARK
# 2448       43  1988     CAN       Canada            BRIAN MULRONEY
# 2600       44  1989     CAN       Canada                    CLARK
# 2755       45  1990     CAN       Canada                Mr. CLARK
# 2911       46  1991     CAN       Canada                McDOIJGALL
# 3075       47  1992     CAN       Canada            Mrs. MCDOUGALL
# 3243       48  1993     CAN       Canada         MRS. KIM CAMPBELL
# 3419       49  1994     CAN       Canada               Mr. Ouellet
# 3597       50  1995     CAN       Canada               Mr. Ouellet
# 3769       51  1996     CAN       Canada            Lloyd Axworthy
# 3950       52  1997     CAN       Canada            Lloyd Axworthy
# 4126       53  1998     CAN       Canada            Lloyd Axworthy
# 4306       54  1999     CAN       Canada            Lloyd Axworthy
# 4487       55  2000     CAN       Canada            Lloyd Axworthy
# 4666       56  2001     CAN       Canada               John Manley
# 4855       57  2002     CAN       Canada            William Graham
# 5043       58  2003     CAN       Canada             Jean Chrétien
# 5232       59  2004     CAN       Canada               Paul Martin
# 5423       60  2005     CAN       Canada  Pierre Stewart Pettigrew
# 5609       61  2006     CAN       Canada            Stephen Harper
# 5802       62  2007     CAN       Canada            Maxime Bernier
# 5993       63  2008     CAN       Canada           Leonard Edwards
# 6185       64  2009     CAN       Canada           Lawrence Cannon
# 6378       65  2010     CAN       Canada            Stephen Harper
# 6567       66  2011     CAN       Canada                John Baird
# 6761       67  2012     CAN       Canada                John Baird
# 6956       68  2013     CAN       Canada                John Baird
# 4487  I would like to begin by\ncongratulating you, ...
# 4666  ﻿It is indeed an honour to\nbe here in New Yor...
# 4855  ﻿I would like, through\nyou, Sir, to congratul...
# 5043  ﻿It is a\ngreat pleasure for me to address thi...
# 5232  I want to talk today about\nUnited Nations ref...
# 5423  The\nsixtieth anniversary of the United Nation...
# 5609  It is a \ngreat honour for me, as Prime Minist...
# 5802  It is an \nhonour for me to speak before this ...
# 5993  I am honoured to be here \ntoday on behalf of ...
# 6185  The \nestablishment of the United Nations came...
# 6378  It has \nnow been more than 65 years since the...
# 6567  Nearly 66 years ago, in \n1946, one of my pred...
# 6761  ﻿It is an\nhonour to address the opening of th...
# 6956  As we gather near Ground \nZero, site of the W...
# 7149  It is both \nan honour and a pleasure for me t...
# 7343  I am honoured to appear before the Assembly to...

# %%
# Initialize stopwords
import nltk
nltk.download('stopwords')

stopwords = set(nltk.corpus.stopwords.words('english'))

# Words that identify the country being referred to. Makes classification trivial.
# Removing them prevents the model from simply learning to associate these terms with the target classes
include_stopwords = {'dear', 'regards', 'must', 'would', 'also', 
                     'canada', 'canadian', 'canadians', 'prime', 'minister', 'province', 'provinces'
                     'united', 'states', 'state', 'america', 'american', 'president','secretary'}
exclude_stopwords = {'against'}

stopwords |= include_stopwords
stopwords -= exclude_stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/stephanegoulet/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# build a text processing and classifier pipeline
# to predict the country (USA or Canada) of a speech
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

df2 = df[df['country'].isin(['USA', 'CAN'])]

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df2['text'], df2['country'], test_size=0.2)

# Create a pipeline that first transforms the text data into TF-IDF vectors (term frequency–inverse document frequency, a measure of importance of a word to a document in a collection), 
# then applies SVM
text_clf = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words=list(stopwords))),
    ('clf', svm.SVC()),
])

# Train the classifier
text_clf.fit(X_train, y_train)

# Predict the test set results
y_pred = text_clf.predict(X_test)

# Print the classification report
print(classification_report(y_test, y_pred, target_names=['USA', 'CAN']))
# Out:
#               precision    recall  f1-score   support
#
#          USA       0.82      1.00      0.90         9
#          CAN       1.00      0.80      0.89        10
#
#     accuracy                           0.89        19
#    macro avg       0.91      0.90      0.89        19
# weighted avg       0.91      0.89      0.89        19

# %%
# This script creates a new column 'sentiment' in the dataframe, 
# which contains the sentiment score of the text. 
# The sentiment score is a float within the range [-1.0, 1.0], 
# where -1.0 denotes a very negative sentiment, 
# 1.0 denotes a very positive sentiment, 
# and values around 0 denote a neutral sentiment.

from textblob import TextBlob

# Define a function to apply sentiment analysis to a text
def get_sentiment(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity  # returns a value between -1 and 1

# Create a new column 'sentiment' in the DataFrame
df2['sentiment'] = df2['text'].apply(get_sentiment)

# Display the DataFrame
df2
# Out:
#       session  year country   country_name          speaker  \
# 8          25  1970     CAN         Canada        Mr. SHARP
# 65         25  1970     USA  United States         Mr. YOST
# 84         26  1971     CAN         Canada        Mr- Sharp
# 179        26  1971     USA  United States       Mr. ROGERS
# 204        27  1972     CAN         Canada       Mr. Sharp
# ...       ...   ...     ...            ...              ...
# 7107       68  2013     USA  United States     Barack Obama
# 7149       69  2014     CAN         Canada   Stephen Harper
# 7301       69  2014     USA  United States     Barack Obama
# 7343       70  2015     CAN         Canada  Mr. Daniel Jean
# 7495       70  2015     USA  United States     Barack Obama
#
#                              position  \
# 8                                 NaN
# 65                                NaN
# 84                                NaN
# 179                               NaN
# 204                               NaN
# ...                               ...
# 7107                        President
# 7149                   Prime Minister
# 7301                        President
# 7343  Deputy Minister Foreign Affairs
# 7495                        President
#
#                                                    text  sentiment
# 8     \nThe General Assembly is fortunate indeed to ...   0.107194
# 65    1.\t It is my privilege to extend to you once ...   0.122693
# 84    48.\t  May I first offer you, Sir, the fiM sup...   0.136800
# 179    Mr. President, I should like first of all to ...   0.121212
# 204   Mr. President, the Canadian delegation looks f...   0.117961
# ...                                                 ...        ...
# 7107  Each year we come together to \nreaffirm the f...   0.060037
# 7149  It is both \nan honour and a pleasure for me t...   0.151988
# 7301  We come together at a \ncrossroads between war...   0.086555
# 7343  I am honoured to appear before the Assembly to...   0.107947
# 7495  Seventy years after the founding of the United...   0.139025
#
# [92 rows x 8 columns]

# %%
# Average sentiment for each country in df2
df2.groupby('country')['sentiment'].mean()
# Out:
# country
# CAN    0.112540
# USA    0.110635
# Name: sentiment, dtype: float64

# %%
# Average sentiment for each speaker in df2
# order the results from most positive to most negative

df2.groupby('speaker')['sentiment'].mean().sort_values(ascending=False).head(5)
# Out:
# speaker
# Condoleezza Rice    0.164408
# Lawrence Cannon     0.152515
# Leonard Edwards     0.145419
# Mr. MACGUIGAN       0.144525
# Jean Chrétien       0.142099
# Name: sentiment, dtype: float64

# %%
# The average sentiment for each year sorted in descending order based on their average sentiment.
df2.groupby('year')['sentiment'].mean().sort_values(ascending=False)
# Out:
# year
# 2008    0.143186
# 1989    0.140575
# 1991    0.139629
# 2003    0.137859
# 1981    0.135435
# 1971    0.129006
# 1994    0.128335
# 1993    0.126281
# 2006    0.125876
# 1995    0.125568
# 1973    0.125375
# 1997    0.124643
# 2015    0.123486
# 2010    0.122846
# 2005    0.121935
# 1987    0.121119
# 2014    0.119271
# 1998    0.117136
# 2009    0.116599
# 2007    0.116335
# 1970    0.114943
# 1983    0.114040
# 1978    0.113078
# 1976    0.111378
# 1977    0.111315
# 1984    0.110240
# 1996    0.109673
# 1988    0.109235
# 1992    0.107583
# 2004    0.106383
# 1990    0.104914
# 1985    0.103662
# 1972    0.100319
# 2001    0.099462
# 2011    0.099054
# 1974    0.098554
# 1980    0.097081
# 2000    0.095660
# 1979    0.095185
# 1982    0.093348
# 1999    0.093205
# 1975    0.090080
# 2002    0.084102
# 1986    0.084058
# 2012    0.074286
# 2013    0.071692
# Name: sentiment, dtype: float64
